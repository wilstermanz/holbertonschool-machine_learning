# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Set up

# %%
# saving of efficientnet is not supported by current tf version

# !pip install tensorflow==2.9.1 --quiet
import tensorflow as tf
print(tf.__version__)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 KB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 61.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.8 MB/s eta 0:00:00
# 2.9.1

# %%
import tensorflow.keras as K
import numpy as np

# %% [markdown]
# # Test 0
#
# Default parameters

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu'):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=7,
        strides=1,
        padding='valid',
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(flat)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.1
    decay_rate = 1

    # create model

    model = build_model(init, activation)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True)
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  resizing_1 (Resizing)       (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  average_pooling2d_1 (Averag  (None, 1, 1, 1408)       0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 1408)              0
#
#  dense_1 (Dense)             (None, 10)                14090
#
# =================================================================
# Total params: 8,783,464
# Trainable params: 14,090
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 141s 85ms/step - loss: 0.3698 - accuracy: 0.8815 - val_loss: 0.2508 - val_accuracy: 0.9161
# Epoch 2/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2693 - accuracy: 0.9100 - val_loss: 0.2330 - val_accuracy: 0.9232
# Epoch 3/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2462 - accuracy: 0.9174 - val_loss: 0.2195 - val_accuracy: 0.9274
# Epoch 4/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2312 - accuracy: 0.9211 - val_loss: 0.2192 - val_accuracy: 0.9277
# Epoch 5/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2245 - accuracy: 0.9231 - val_loss: 0.2184 - val_accuracy: 0.9273
# Epoch 6/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2171 - accuracy: 0.9258 - val_loss: 0.2218 - val_accuracy: 0.9253
# Epoch 7/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2129 - accuracy: 0.9261 - val_loss: 0.2153 - val_accuracy: 0.9278
# Epoch 8/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2056 - accuracy: 0.9289 - val_loss: 0.2138 - val_accuracy: 0.9282
# Epoch 9/100
# 1563/1563 [==============================] - 129s 82ms/step - loss: 0.2045 - accuracy: 0.9297 - val_loss: 0.2105 - val_accuracy: 0.9322
# Epoch 10/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.1983 - accuracy: 0.9317 - val_loss: 0.2139 - val_accuracy: 0.9287
# Epoch 11/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.1966 - accuracy: 0.9318 - val_loss: 0.2148 - val_accuracy: 0.9289

# %% [markdown]
# # Test 1
# - reduced image resizing to 150px

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu'):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=5,
        strides=1,
        padding='valid',
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(flat)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.1
    decay_rate = 1

    # create model

    model = build_model(init, activation)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_25 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_12 (Resizing)      (None, 150, 150, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 5, 5, 1408)       8769374
#  al)
#
#  average_pooling2d_1 (Averag  (None, 1, 1, 1408)       0
#  ePooling2D)
#
#  flatten_12 (Flatten)        (None, 1408)              0
#
#  dense_45 (Dense)            (None, 10)                14090
#
# =================================================================
# Total params: 8,783,464
# Trainable params: 14,090
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 80s 46ms/step - loss: 0.4112 - accuracy: 0.8682 - val_loss: 0.2849 - val_accuracy: 0.9023
# Epoch 2/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.2954 - accuracy: 0.9007 - val_loss: 0.2595 - val_accuracy: 0.9119
# Epoch 3/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.2787 - accuracy: 0.9067 - val_loss: 0.2568 - val_accuracy: 0.9154
# Epoch 4/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.2636 - accuracy: 0.9124 - val_loss: 0.2476 - val_accuracy: 0.9175
# Epoch 5/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.2522 - accuracy: 0.9148 - val_loss: 0.2452 - val_accuracy: 0.9177
# Epoch 6/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.2442 - accuracy: 0.9167 - val_loss: 0.2520 - val_accuracy: 0.9145
# Epoch 7/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.2404 - accuracy: 0.9175 - val_loss: 0.2458 - val_accuracy: 0.9181

# %% [markdown]
# # Test 2
# - Increased batch size

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu'):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=5,
        strides=1,
        padding='valid',
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(flat)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 512
    epochs = 100
    alpha = 0.1
    decay_rate = 1

    # create model

    model = build_model(init, activation)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                 K.callbacks.LearningRateScheduler(
                    schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                    verbose=True),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  resizing_4 (Resizing)       (None, 150, 150, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 5, 5, 1408)       8769374
#  al)
#
#  average_pooling2d_4 (Averag  (None, 1, 1, 1408)       0
#  ePooling2D)
#
#  flatten_4 (Flatten)         (None, 1408)              0
#
#  dense_4 (Dense)             (None, 10)                14090
#
# =================================================================
# Total params: 8,783,464
# Trainable params: 14,090
# Non-trainable params: 8,769,374
# _________________________________________________________________
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.1.
# Epoch 1/100
# 98/98 [==============================] - 79s 681ms/step - loss: 1.1698 - accuracy: 0.8491 - val_loss: 0.8566 - val_accuracy: 0.8787 - lr: 0.1000
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.05.
# Epoch 2/100
# 98/98 [==============================] - 58s 594ms/step - loss: 0.6725 - accuracy: 0.8866 - val_loss: 0.5774 - val_accuracy: 0.9008 - lr: 0.0500
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.03333333333333333.
# Epoch 3/100
# 98/98 [==============================] - 57s 587ms/step - loss: 0.4882 - accuracy: 0.8976 - val_loss: 0.4805 - val_accuracy: 0.9030 - lr: 0.0333
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.025.
# Epoch 4/100
# 98/98 [==============================] - 58s 590ms/step - loss: 0.4075 - accuracy: 0.9039 - val_loss: 0.4448 - val_accuracy: 0.9045 - lr: 0.0250
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.02.
# Epoch 5/100
# 98/98 [==============================] - 57s 588ms/step - loss: 0.3576 - accuracy: 0.9089 - val_loss: 0.4243 - val_accuracy: 0.9017 - lr: 0.0200
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.016666666666666666.
# Epoch 6/100
# 98/98 [==============================] - 57s 587ms/step - loss: 0.3335 - accuracy: 0.9107 - val_loss: 0.3901 - val_accuracy: 0.9051 - lr: 0.0167
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.014285714285714287.
# Epoch 7/100
# 98/98 [==============================] - 57s 587ms/step - loss: 0.3063 - accuracy: 0.9147 - val_loss: 0.3809 - val_accuracy: 0.9093 - lr: 0.0143
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0125.
# Epoch 8/100
# 98/98 [==============================] - 57s 588ms/step - loss: 0.2992 - accuracy: 0.9153 - val_loss: 0.3493 - val_accuracy: 0.9111 - lr: 0.0125
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.011111111111111112.
# Epoch 9/100
# 98/98 [==============================] - 57s 583ms/step - loss: 0.2820 - accuracy: 0.9161 - val_loss: 0.3553 - val_accuracy: 0.9099 - lr: 0.0111
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.01.
# Epoch 10/100
# 98/98 [==============================] - 58s 589ms/step - loss: 0.2735 - accuracy: 0.9177 - val_loss: 0.3383 - val_accuracy: 0.9101 - lr: 0.0100
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.009090909090909092.
# Epoch 11/100
# 98/98 [==============================] - 58s 589ms/step - loss: 0.2612 - accuracy: 0.9206 - val_loss: 0.3322 - val_accuracy: 0.9120 - lr: 0.0091
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.008333333333333333.
# Epoch 12/100
# 98/98 [==============================] - 58s 589ms/step - loss: 0.2478 - accuracy: 0.9238 - val_loss: 0.3274 - val_accuracy: 0.9139 - lr: 0.0083
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.007692307692307693.
# Epoch 13/100
# 98/98 [==============================] - 58s 589ms/step - loss: 0.2424 - accuracy: 0.9231 - val_loss: 0.3262 - val_accuracy: 0.9127 - lr: 0.0077
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0071428571428571435.
# Epoch 14/100
# 98/98 [==============================] - 58s 588ms/step - loss: 0.2381 - accuracy: 0.9240 - val_loss: 0.3157 - val_accuracy: 0.9136 - lr: 0.0071
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.006666666666666667.
# Epoch 15/100
# 98/98 [==============================] - 58s 589ms/step - loss: 0.2389 - accuracy: 0.9241 - val_loss: 0.3155 - val_accuracy: 0.9138 - lr: 0.0067
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00625.
# Epoch 16/100
# 98/98 [==============================] - 57s 582ms/step - loss: 0.2360 - accuracy: 0.9230 - val_loss: 0.3171 - val_accuracy: 0.9117 - lr: 0.0063
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0058823529411764705.
# Epoch 17/100
# 98/98 [==============================] - 58s 589ms/step - loss: 0.2301 - accuracy: 0.9235 - val_loss: 0.3103 - val_accuracy: 0.9138 - lr: 0.0059
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.005555555555555556.
# Epoch 18/100
# 98/98 [==============================] - 57s 587ms/step - loss: 0.2255 - accuracy: 0.9251 - val_loss: 0.3086 - val_accuracy: 0.9137 - lr: 0.0056
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.005263157894736842.
# Epoch 19/100
# 98/98 [==============================] - 57s 586ms/step - loss: 0.2216 - accuracy: 0.9266 - val_loss: 0.3071 - val_accuracy: 0.9118 - lr: 0.0053
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.005.
# Epoch 20/100
# 98/98 [==============================] - 57s 582ms/step - loss: 0.2206 - accuracy: 0.9266 - val_loss: 0.3085 - val_accuracy: 0.9123 - lr: 0.0050
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.004761904761904762.
# Epoch 21/100
# 98/98 [==============================] - 57s 586ms/step - loss: 0.2208 - accuracy: 0.9254 - val_loss: 0.3027 - val_accuracy: 0.9151 - lr: 0.0048
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.004545454545454546.
# Epoch 22/100
# 98/98 [==============================] - 57s 586ms/step - loss: 0.2141 - accuracy: 0.9290 - val_loss: 0.2977 - val_accuracy: 0.9144 - lr: 0.0045
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.004347826086956522.
# Epoch 23/100
# 98/98 [==============================] - 58s 591ms/step - loss: 0.2140 - accuracy: 0.9279 - val_loss: 0.3022 - val_accuracy: 0.9141 - lr: 0.0043
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.004166666666666667.
# Epoch 24/100
# 98/98 [==============================] - 58s 598ms/step - loss: 0.2160 - accuracy: 0.9269 - val_loss: 0.2930 - val_accuracy: 0.9164 - lr: 0.0042
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.004.
# Epoch 25/100
# 98/98 [==============================] - 57s 582ms/step - loss: 0.2123 - accuracy: 0.9280 - val_loss: 0.2938 - val_accuracy: 0.9148 - lr: 0.0040
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0038461538461538464.
# Epoch 26/100
# 98/98 [==============================] - 57s 583ms/step - loss: 0.2134 - accuracy: 0.9276 - val_loss: 0.2977 - val_accuracy: 0.9118 - lr: 0.0038

# %% [markdown]
# # Test 3
# - Added two fully connected layers for depth after frozen layers
# - Adjusted batch size back down
# - Adjusted learning rate

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu'):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=5,
        strides=1,
        padding='valid',
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # dense layers

    dense1 = K.layers.Dense(
        units = 512,
        activation=activation,
        kernel_initializer=init
        )(flat)

    dense2 = K.layers.Dense(
        units = 128,
        activation=activation,
        kernel_initializer=init
        )(dense1)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense2)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2

    # create model

    model = build_model(init, activation)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                 K.callbacks.LearningRateScheduler(
                    schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                    verbose=True
                    ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_11 (Resizing)      (None, 150, 150, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 5, 5, 1408)       8769374
#  al)
#
#  average_pooling2d_10 (Avera  (None, 1, 1, 1408)       0
#  gePooling2D)
#
#  flatten_10 (Flatten)        (None, 1408)              0
#
#  dense_20 (Dense)            (None, 512)               721408
#
#  dense_21 (Dense)            (None, 128)               65664
#
#  dense_22 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 9,557,736
# Trainable params: 788,362
# Non-trainable params: 8,769,374
# _________________________________________________________________
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.01.
# Epoch 1/100
# 1563/1563 [==============================] - 84s 48ms/step - loss: 0.5081 - accuracy: 0.8502 - val_loss: 0.4137 - val_accuracy: 0.8886 - lr: 0.0100
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.008333333333333333.
# Epoch 2/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3906 - accuracy: 0.8839 - val_loss: 0.3470 - val_accuracy: 0.8990 - lr: 0.0083
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0071428571428571435.
# Epoch 3/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.3373 - accuracy: 0.8995 - val_loss: 0.3479 - val_accuracy: 0.9028 - lr: 0.0071
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0062499999999999995.
# Epoch 4/100
# 1563/1563 [==============================] - 73s 46ms/step - loss: 0.3094 - accuracy: 0.9073 - val_loss: 0.3187 - val_accuracy: 0.9121 - lr: 0.0063
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.005555555555555556.
# Epoch 5/100
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.2728 - accuracy: 0.9168 - val_loss: 0.3261 - val_accuracy: 0.9075 - lr: 0.0056
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.005.
# Epoch 6/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.2536 - accuracy: 0.9210 - val_loss: 0.3398 - val_accuracy: 0.9050 - lr: 0.0050

# %% [markdown]
# # Test 4
# - Adding dropout to reduce overfitting
# - removed learning rate decay

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """
    # set regularizer
    regularizer = K.layers.Dropout(1 - keep_prob)

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=5,
        strides=1,
        padding='valid',
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # dense layers
    dense1 = K.layers.Dense(
        units = 512,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = regularizer(dense1)

    dense2 = K.layers.Dense(
        units = 128,
        activation=activation,
        kernel_initializer=init,
        )(dense1_drop)

    dense2_drop = regularizer(dense2)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense2_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.5

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_29 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  resizing_14 (Resizing)         (None, 150, 150, 3)  0           ['input_29[0][0]']
#
#  efficientnetv2-b2 (Functional)  (None, 5, 5, 1408)  8769374     ['resizing_14[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 1, 1, 1408)  0           ['efficientnetv2-b2[0][0]']
#  ooling2D)
#
#  flatten_13 (Flatten)           (None, 1408)         0           ['average_pooling2d_13[0][0]']
#
#  dense_29 (Dense)               (None, 512)          721408      ['flatten_13[0][0]']
#
#  dropout_2 (Dropout)            multiple             0           ['dense_29[0][0]',
#                                                                   'dense_30[0][0]']
#
#  dense_30 (Dense)               (None, 128)          65664       ['dropout_2[0][0]']
#
#  dense_31 (Dense)               (None, 10)           1290        ['dropout_2[1][0]']
#
# ==================================================================================================
# Total params: 9,557,736
# Trainable params: 788,362
# Non-trainable params: 8,769,374
# __________________________________________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 95s 54ms/step - loss: 0.5132 - accuracy: 0.8370 - val_loss: 0.2945 - val_accuracy: 0.9024
# Epoch 2/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3938 - accuracy: 0.8757 - val_loss: 0.2930 - val_accuracy: 0.9047
# Epoch 3/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3633 - accuracy: 0.8834 - val_loss: 0.2723 - val_accuracy: 0.9086
# Epoch 4/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.3469 - accuracy: 0.8897 - val_loss: 0.2637 - val_accuracy: 0.9111
# Epoch 5/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3326 - accuracy: 0.8946 - val_loss: 0.2633 - val_accuracy: 0.9133
# Epoch 6/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3157 - accuracy: 0.8994 - val_loss: 0.2511 - val_accuracy: 0.9185
# Epoch 7/100
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.3095 - accuracy: 0.9007 - val_loss: 0.2630 - val_accuracy: 0.9148
# Epoch 8/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.2955 - accuracy: 0.9044 - val_loss: 0.2596 - val_accuracy: 0.9139

# %% [markdown]
# # Test 5
# - Reduced depth and width of unfrozen layers

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """
    # set regularizer
    regularizer = K.layers.Dropout(1 - keep_prob)

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=5,
        strides=1,
        padding='valid',
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # dense layers
    dense1 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = regularizer(dense1)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense1_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.5

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_33 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_16 (Resizing)      (None, 150, 150, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 5, 5, 1408)       8769374
#  al)
#
#  average_pooling2d_15 (Avera  (None, 1, 1, 1408)       0
#  gePooling2D)
#
#  flatten_15 (Flatten)        (None, 1408)              0
#
#  dense_41 (Dense)            (None, 100)               140900
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_42 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 8,911,284
# Trainable params: 141,910
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 149s 90ms/step - loss: 0.4691 - accuracy: 0.8504 - val_loss: 0.2847 - val_accuracy: 0.9020
# Epoch 2/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3680 - accuracy: 0.8797 - val_loss: 0.2701 - val_accuracy: 0.9103
# Epoch 3/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3413 - accuracy: 0.8867 - val_loss: 0.2657 - val_accuracy: 0.9099
# Epoch 4/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.3245 - accuracy: 0.8911 - val_loss: 0.2580 - val_accuracy: 0.9132
# Epoch 5/100
# 1563/1563 [==============================] - 73s 46ms/step - loss: 0.3163 - accuracy: 0.8925 - val_loss: 0.2588 - val_accuracy: 0.9129
# Epoch 6/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3012 - accuracy: 0.8980 - val_loss: 0.2570 - val_accuracy: 0.9146
# Epoch 7/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3002 - accuracy: 0.8993 - val_loss: 0.2556 - val_accuracy: 0.9168
# Epoch 8/100
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.2877 - accuracy: 0.9028 - val_loss: 0.2536 - val_accuracy: 0.9130
# Epoch 9/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.2819 - accuracy: 0.9039 - val_loss: 0.2554 - val_accuracy: 0.9139
# Epoch 10/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.2776 - accuracy: 0.9054 - val_loss: 0.2539 - val_accuracy: 0.9146

# %% [markdown]
# # Test 6
# - removed pooling layer and added 1x1 convolutional layers to increase data received from frozen layers
# - increased depth of unfrozen layers
# - reduced keep_prob to prevent overfitting

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # 1x1 convolution
    conv = K.layers.Conv2D(
        filters=250,
        kernel_size=1,
        strides=1,
        padding='valid',
        activation=activation,
        kernel_initializer=init
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(conv)

    # dense layers
    dense1 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = K.layers.Dropout(1 - keep_prob)(dense1)

    dense2 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense1_drop)

    dense2_drop = K.layers.Dropout(1 - keep_prob)(dense2)

    dense3 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense2_drop)

    dense3_drop = K.layers.Dropout(1 - keep_prob)(dense3)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense3_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.7

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_10 (Resizing)      (None, 150, 150, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 5, 5, 1408)       8769374
#  al)
#
#  conv2d_8 (Conv2D)           (None, 5, 5, 250)         352250
#
#  flatten_10 (Flatten)        (None, 6250)              0
#
#  dense_37 (Dense)            (None, 100)               625100
#
#  dropout_23 (Dropout)        (None, 100)               0
#
#  dense_38 (Dense)            (None, 100)               10100
#
#  dropout_24 (Dropout)        (None, 100)               0
#
#  dense_39 (Dense)            (None, 100)               10100
#
#  dropout_25 (Dropout)        (None, 100)               0
#
#  dense_40 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 9,767,934
# Trainable params: 998,560
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 130s 49ms/step - loss: 0.6931 - accuracy: 0.7902 - val_loss: 0.3173 - val_accuracy: 0.9107
# Epoch 2/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 0.4209 - accuracy: 0.8791 - val_loss: 0.2920 - val_accuracy: 0.9183
# Epoch 3/100
# 1563/1563 [==============================] - 83s 53ms/step - loss: 0.3558 - accuracy: 0.8959 - val_loss: 0.2830 - val_accuracy: 0.9158
# Epoch 4/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.3105 - accuracy: 0.9083 - val_loss: 0.2664 - val_accuracy: 0.9214
# Epoch 5/100
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.2922 - accuracy: 0.9144 - val_loss: 0.2620 - val_accuracy: 0.9217
# Epoch 6/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.2697 - accuracy: 0.9216 - val_loss: 0.2504 - val_accuracy: 0.9248
# Epoch 7/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.2420 - accuracy: 0.9303 - val_loss: 0.2692 - val_accuracy: 0.9271
# Epoch 8/100
# 1563/1563 [==============================] - 74s 48ms/step - loss: 0.2264 - accuracy: 0.9341 - val_loss: 0.2496 - val_accuracy: 0.9255
# Epoch 9/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.2138 - accuracy: 0.9376 - val_loss: 0.2387 - val_accuracy: 0.9330
# Epoch 10/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.2014 - accuracy: 0.9424 - val_loss: 0.2655 - val_accuracy: 0.9271
# Epoch 11/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.1891 - accuracy: 0.9460 - val_loss: 0.2511 - val_accuracy: 0.9284

# %% [markdown]
# # Test 7
# - Removed 1x1 convolutional layer

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=150,
        width=150,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(150, 150, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # 1x1 convolution
    # conv = K.layers.Conv2D(
    #     filters=250,
    #     kernel_size=1,
    #     strides=1,
    #     padding='valid',
    #     activation=activation,
    #     kernel_initializer=init
    #     )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(frozen_layers)

    # dense layers
    dense1 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = K.layers.Dropout(1 - keep_prob)(dense1)

    dense2 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense1_drop)

    dense2_drop = K.layers.Dropout(1 - keep_prob)(dense2)

    dense3 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense2_drop)

    dense3_drop = K.layers.Dropout(1 - keep_prob)(dense3)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense3_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.7

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  resizing_4 (Resizing)       (None, 150, 150, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 5, 5, 1408)       8769374
#  al)
#
#  flatten_4 (Flatten)         (None, 35200)             0
#
#  dense_16 (Dense)            (None, 100)               3520100
#
#  dropout_8 (Dropout)         (None, 100)               0
#
#  dense_17 (Dense)            (None, 100)               10100
#
#  dropout_9 (Dropout)         (None, 100)               0
#
#  dense_18 (Dense)            (None, 100)               10100
#
#  dropout_10 (Dropout)        (None, 100)               0
#
#  dense_19 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 12,310,684
# Trainable params: 3,541,310
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 92s 53ms/step - loss: 0.6557 - accuracy: 0.8099 - val_loss: 0.2952 - val_accuracy: 0.9091
# Epoch 2/100
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.3869 - accuracy: 0.8852 - val_loss: 0.2916 - val_accuracy: 0.9133
# Epoch 3/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.3350 - accuracy: 0.9006 - val_loss: 0.2793 - val_accuracy: 0.9137
# Epoch 4/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.2907 - accuracy: 0.9135 - val_loss: 0.2676 - val_accuracy: 0.9195
# Epoch 5/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.2620 - accuracy: 0.9199 - val_loss: 0.2719 - val_accuracy: 0.9205
# Epoch 6/100
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.2425 - accuracy: 0.9267 - val_loss: 0.2638 - val_accuracy: 0.9206
# Epoch 7/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.2284 - accuracy: 0.9324 - val_loss: 0.2776 - val_accuracy: 0.9231
# Epoch 8/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.2041 - accuracy: 0.9384 - val_loss: 0.2773 - val_accuracy: 0.9195

# %% [markdown]
# # Test 8
# - Increased image resizing to 224x224
# - increased patience

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # 1x1 convolution
    conv = K.layers.Conv2D(
        filters=250,
        kernel_size=1,
        strides=1,
        padding='valid',
        activation=activation,
        kernel_initializer=init
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(conv)

    # dense layers
    dense1 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = K.layers.Dropout(1 - keep_prob)(dense1)

    dense2 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense1_drop)

    dense2_drop = K.layers.Dropout(1 - keep_prob)(dense2)

    dense3 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense2_drop)

    dense3_drop = K.layers.Dropout(1 - keep_prob)(dense3)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense3_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 3
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.7

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_13 (Resizing)      (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 250)         352250
#
#  flatten_13 (Flatten)        (None, 12250)             0
#
#  dense_46 (Dense)            (None, 100)               1225100
#
#  dropout_29 (Dropout)        (None, 100)               0
#
#  dense_47 (Dense)            (None, 100)               10100
#
#  dropout_30 (Dropout)        (None, 100)               0
#
#  dense_48 (Dense)            (None, 100)               10100
#
#  dropout_31 (Dropout)        (None, 100)               0
#
#  dense_49 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 10,367,934
# Trainable params: 1,598,560
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 137s 82ms/step - loss: 0.9058 - accuracy: 0.6925 - val_loss: 0.3790 - val_accuracy: 0.8986
# Epoch 2/100
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.5068 - accuracy: 0.8527 - val_loss: 0.2943 - val_accuracy: 0.9174
# Epoch 3/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.4191 - accuracy: 0.8822 - val_loss: 0.2830 - val_accuracy: 0.9249
# Epoch 4/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.3717 - accuracy: 0.8945 - val_loss: 0.2699 - val_accuracy: 0.9246
# Epoch 5/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.3400 - accuracy: 0.9033 - val_loss: 0.2485 - val_accuracy: 0.9320
# Epoch 6/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.3136 - accuracy: 0.9119 - val_loss: 0.2688 - val_accuracy: 0.9255
# Epoch 7/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.2995 - accuracy: 0.9177 - val_loss: 0.2549 - val_accuracy: 0.9299
# Epoch 8/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.2788 - accuracy: 0.9217 - val_loss: 0.2399 - val_accuracy: 0.9302
# Epoch 9/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.2606 - accuracy: 0.9281 - val_loss: 0.2364 - val_accuracy: 0.9330
# Epoch 10/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.2491 - accuracy: 0.9317 - val_loss: 0.2260 - val_accuracy: 0.9378
# Epoch 11/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2407 - accuracy: 0.9356 - val_loss: 0.2463 - val_accuracy: 0.9301
# Epoch 12/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2368 - accuracy: 0.9362 - val_loss: 0.2553 - val_accuracy: 0.9326
# Epoch 13/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2207 - accuracy: 0.9397 - val_loss: 0.2502 - val_accuracy: 0.9342

# %% [markdown]
# # Test 9
# - Increased features before fully connected layers

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # 1x1 convolution
    conv = K.layers.Conv2D(
        filters=704,
        kernel_size=1,
        strides=1,
        padding='valid',
        activation=activation,
        kernel_initializer=init
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(conv)

    # dense layers
    dense1 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = K.layers.Dropout(1 - keep_prob)(dense1)

    dense2 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense1_drop)

    dense2_drop = K.layers.Dropout(1 - keep_prob)(dense2)

    dense3 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense2_drop)

    dense3_drop = K.layers.Dropout(1 - keep_prob)(dense3)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense3_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 3
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.7

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_29 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_14 (Resizing)      (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 704)         991936
#
#  flatten_14 (Flatten)        (None, 34496)             0
#
#  dense_50 (Dense)            (None, 100)               3449700
#
#  dropout_32 (Dropout)        (None, 100)               0
#
#  dense_51 (Dense)            (None, 100)               10100
#
#  dropout_33 (Dropout)        (None, 100)               0
#
#  dense_52 (Dense)            (None, 100)               10100
#
#  dropout_34 (Dropout)        (None, 100)               0
#
#  dense_53 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 13,232,220
# Trainable params: 4,462,846
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 140s 84ms/step - loss: 1.3668 - accuracy: 0.5030 - val_loss: 0.5013 - val_accuracy: 0.8119
# Epoch 2/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.7227 - accuracy: 0.7245 - val_loss: 0.4342 - val_accuracy: 0.8215
# Epoch 3/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.5835 - accuracy: 0.7692 - val_loss: 0.4189 - val_accuracy: 0.8319
# Epoch 4/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.5363 - accuracy: 0.7857 - val_loss: 0.3822 - val_accuracy: 0.8343
# Epoch 5/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.4987 - accuracy: 0.7984 - val_loss: 0.3706 - val_accuracy: 0.8367
# Epoch 6/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.4816 - accuracy: 0.8037 - val_loss: 0.3695 - val_accuracy: 0.8373
# Epoch 7/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.4443 - accuracy: 0.8147 - val_loss: 0.3811 - val_accuracy: 0.8379
# Epoch 8/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.4396 - accuracy: 0.8175 - val_loss: 0.3612 - val_accuracy: 0.8424
# Epoch 9/100
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.4318 - accuracy: 0.8181 - val_loss: 0.3809 - val_accuracy: 0.8378
# Epoch 10/100
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.4127 - accuracy: 0.8247 - val_loss: 0.3736 - val_accuracy: 0.8334
# Epoch 11/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.4091 - accuracy: 0.8256 - val_loss: 0.3637 - val_accuracy: 0.8382

# %% [markdown]
# # Test 10
# - Decreased features before fully connected layers

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu',
                keep_prob=0.5):
    """
    Returns compiled model
    """

    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # 1x1 convolution
    conv = K.layers.Conv2D(
        filters=176,
        kernel_size=1,
        strides=1,
        padding='valid',
        activation=activation,
        kernel_initializer=init
        )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(conv)

    # dense layers
    dense1 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(flat)

    dense1_drop = K.layers.Dropout(1 - keep_prob)(dense1)

    dense2 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense1_drop)

    dense2_drop = K.layers.Dropout(1 - keep_prob)(dense2)

    dense3 = K.layers.Dense(
        units = 100,
        activation=activation,
        kernel_initializer=init,
        )(dense2_drop)

    dense3_drop = K.layers.Dropout(1 - keep_prob)(dense3)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(dense3_drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 3
    batch_size = 32
    epochs = 100
    alpha = 0.01
    decay_rate = 0.2
    keep_prob = 0.7

    # create model
    model = build_model(init, activation, keep_prob)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True
                #     ),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True
                    ),
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_35 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_17 (Resizing)      (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  conv2d_14 (Conv2D)          (None, 7, 7, 176)         247984
#
#  flatten_17 (Flatten)        (None, 8624)              0
#
#  dense_62 (Dense)            (None, 100)               862500
#
#  dropout_41 (Dropout)        (None, 100)               0
#
#  dense_63 (Dense)            (None, 100)               10100
#
#  dropout_42 (Dropout)        (None, 100)               0
#
#  dense_64 (Dense)            (None, 100)               10100
#
#  dropout_43 (Dropout)        (None, 100)               0
#
#  dense_65 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 9,901,068
# Trainable params: 1,131,694
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 230s 82ms/step - loss: 0.7164 - accuracy: 0.7818 - val_loss: 0.3418 - val_accuracy: 0.9077
# Epoch 2/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.3921 - accuracy: 0.8893 - val_loss: 0.2584 - val_accuracy: 0.9245
# Epoch 3/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.3285 - accuracy: 0.9072 - val_loss: 0.2607 - val_accuracy: 0.9259
# Epoch 4/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2888 - accuracy: 0.9174 - val_loss: 0.2412 - val_accuracy: 0.9313
# Epoch 5/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.2673 - accuracy: 0.9249 - val_loss: 0.2324 - val_accuracy: 0.9334
# Epoch 6/100
# 1563/1563 [==============================] - 123s 79ms/step - loss: 0.2427 - accuracy: 0.9316 - val_loss: 0.2383 - val_accuracy: 0.9327
# Epoch 7/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.2297 - accuracy: 0.9353 - val_loss: 0.2369 - val_accuracy: 0.9348
# Epoch 8/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.2130 - accuracy: 0.9407 - val_loss: 0.2367 - val_accuracy: 0.9336

# %% [markdown]
# # Test 11
# - Same as test 0, with pooling layer removed

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu'):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # pooling
    # pool = K.layers.AvgPool2D(
    #     pool_size=7,
    #     strides=1,
    #     padding='valid',
    #     )(frozen_layers)

    # flatten layer
    flat = K.layers.Flatten()(frozen_layers)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(flat)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.1
    decay_rate = 1

    # create model

    model = build_model(init, activation)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True)
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_37 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  resizing_18 (Resizing)      (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  flatten_18 (Flatten)        (None, 68992)             0
#
#  dense_66 (Dense)            (None, 10)                689930
#
# =================================================================
# Total params: 9,459,304
# Trainable params: 689,930
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 136s 82ms/step - loss: 2.0502 - accuracy: 0.8707 - val_loss: 2.0979 - val_accuracy: 0.9018
# Epoch 2/100
# 1563/1563 [==============================] - 123s 79ms/step - loss: 1.3260 - accuracy: 0.9298 - val_loss: 2.1443 - val_accuracy: 0.9143
# Epoch 3/100
# 1563/1563 [==============================] - 123s 79ms/step - loss: 1.0991 - accuracy: 0.9434 - val_loss: 2.4021 - val_accuracy: 0.9223

# %% [markdown]
# # Test 12
# - Similar to initial test, but added 1x1 convolution to remove features

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(), activation='relu'):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # Reduce features
    conv = K.layers.Conv2D(
        filters=250,
        kernel_size=1,
        strides=1,
        padding='valid',
        activation=activation,
        kernel_initializer=init
        )(frozen_layers)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=7,
        strides=1,
        padding='valid',
        )(conv)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(flat)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 2
    batch_size = 32
    epochs = 100
    alpha = 0.1
    decay_rate = 1

    # create model

    model = build_model(init, activation)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True)
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  resizing (Resizing)         (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  conv2d (Conv2D)             (None, 7, 7, 250)         352250
#
#  average_pooling2d (AverageP  (None, 1, 1, 250)        0
#  ooling2D)
#
#  flatten (Flatten)           (None, 250)               0
#
#  dense (Dense)               (None, 10)                2510
#
# =================================================================
# Total params: 9,124,134
# Trainable params: 354,760
# Non-trainable params: 8,769,374
# _________________________________________________________________
# /usr/local/lib/python3.9/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer HeNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 1/100
# 1563/1563 [==============================] - 151s 84ms/step - loss: 0.3166 - accuracy: 0.8946 - val_loss: 0.2321 - val_accuracy: 0.9227
# Epoch 2/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.2260 - accuracy: 0.9216 - val_loss: 0.2223 - val_accuracy: 0.9249
# Epoch 3/100
# 1563/1563 [==============================] - 129s 82ms/step - loss: 0.1916 - accuracy: 0.9340 - val_loss: 0.1923 - val_accuracy: 0.9352
# Epoch 4/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.1667 - accuracy: 0.9423 - val_loss: 0.1924 - val_accuracy: 0.9366
# Epoch 5/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.1466 - accuracy: 0.9489 - val_loss: 0.1904 - val_accuracy: 0.9397
# Epoch 6/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.1327 - accuracy: 0.9532 - val_loss: 0.2054 - val_accuracy: 0.9358
# Epoch 7/100
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.1176 - accuracy: 0.9585 - val_loss: 0.2064 - val_accuracy: 0.9356

# %% [markdown]
# # Test 13
# - added dropout

# %%
def preprocess_data(X, Y):
    """
    Returns unpacked and preprocessed data
    """
    X_p, Y_p = X, K.utils.to_categorical(Y, num_classes=10)
    return X_p, Y_p


def build_model(init=K.initializers.he_normal(),
                activation='relu',
                keep_rate=.5):
    """
    Returns compiled model
    """
    # create input layer
    input = K.layers.Input(shape=(32, 32, 3))

    # resizing layer
    resize = K.layers.Resizing(
        height=224,
        width=224,
        interpolation="bilinear",
        crop_to_aspect_ratio=False)(input)

    # EfficientNet
    eNet = K.applications.EfficientNetV2B2(
        weights='imagenet',
        input_shape=(224, 224, 3),
        include_top=False,
        )
    eNet.trainable = False

    # Freeze previous layers
    frozen_layers = eNet(resize)

    # Reduce features
    conv = K.layers.Conv2D(
        filters=250,
        kernel_size=1,
        strides=1,
        padding='valid',
        activation=activation,
        kernel_initializer=init
        )(frozen_layers)

    # pooling
    pool = K.layers.AvgPool2D(
        pool_size=7,
        strides=1,
        padding='valid',
        )(conv)

    # flatten layer
    flat = K.layers.Flatten()(pool)

    # dropout
    drop = K.layers.Dropout(1 - keep_rate)(flat)

    # output
    output = K.layers.Dense(
        units=10,
        activation='softmax',
        kernel_initializer=init
        )(drop)
    
    # build model
    model = K.models.Model(input, output)

    # compile model
    model.compile(optimizer=K.optimizers.Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

if __name__ == "__main__":
    # download and preprocess data
    (x_train, y_train), (x_valid, y_valid) = K.datasets.cifar10.load_data()
    x_train, y_train = preprocess_data(x_train, y_train)
    x_valid, y_valid = preprocess_data(x_valid, y_valid)

    # define hyperparameters
    init = K.initializers.he_normal()
    activation = 'relu'
    patience = 3
    batch_size = 32
    epochs = 100
    alpha = 0.1
    decay_rate = 1
    keep_rate = .7

    # create model

    model = build_model(init, activation, keep_rate)

    model.summary()

    # callbacks
    callbacks = [K.callbacks.EarlyStopping(patience=patience),
                #  K.callbacks.LearningRateScheduler(
                #     schedule=lambda epoch: alpha / (1 + epoch * decay_rate),
                #     verbose=True),
                 K.callbacks.ModelCheckpoint(
                    filepath='cifar10.h5',
                    monitor='val_loss',
                    save_best_only=True)
                 ]

    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                    validation_data=(x_valid, y_valid), callbacks=callbacks)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  resizing_1 (Resizing)       (None, 224, 224, 3)       0
#
#  efficientnetv2-b2 (Function  (None, 7, 7, 1408)       8769374
#  al)
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 250)         352250
#
#  average_pooling2d_1 (Averag  (None, 1, 1, 250)        0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 250)               0
#
#  dropout_1 (Dropout)         (None, 250)               0
#
#  dense_1 (Dense)             (None, 10)                2510
#
# =================================================================
# Total params: 9,124,134
# Trainable params: 354,760
# Non-trainable params: 8,769,374
# _________________________________________________________________
# Epoch 1/100
# 1563/1563 [==============================] - 139s 83ms/step - loss: 0.3483 - accuracy: 0.8834 - val_loss: 0.2290 - val_accuracy: 0.9232
# Epoch 2/100
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.2553 - accuracy: 0.9130 - val_loss: 0.2090 - val_accuracy: 0.9294
# Epoch 3/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.2273 - accuracy: 0.9227 - val_loss: 0.2088 - val_accuracy: 0.9288
# Epoch 4/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.2075 - accuracy: 0.9293 - val_loss: 0.1957 - val_accuracy: 0.9368
# Epoch 5/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.1903 - accuracy: 0.9344 - val_loss: 0.1984 - val_accuracy: 0.9361
# Epoch 6/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.1788 - accuracy: 0.9385 - val_loss: 0.1869 - val_accuracy: 0.9380
# Epoch 7/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.1671 - accuracy: 0.9414 - val_loss: 0.2009 - val_accuracy: 0.9340
# Epoch 8/100
# 1563/1563 [==============================] - 125s 80ms/step - loss: 0.1573 - accuracy: 0.9447 - val_loss: 0.1896 - val_accuracy: 0.9405
# Epoch 9/100
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.1511 - accuracy: 0.9480 - val_loss: 0.1876 - val_accuracy: 0.9410
